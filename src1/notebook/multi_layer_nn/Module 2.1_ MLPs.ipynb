# %% [markdown]
# ## Module 2.1: Working with MLPs in Keras (A Review)
#
# This is a quick review of working with MLPs. We want to get everyone on the same level as we proceed. In this module we will pay attention to:
# 1. Using the Keras functional API for defining models.
# 2. Implementing different types of regularization.
# 3. Implementing batch normalization.
# 4. Working with validation data and early stopping.
#
# Those students who are comfortable with all these matters might consider skipping ahead.
#
# Note that we will not spend time tuning hyper-parameters: The purpose is to show how different techniques can be implemented in Keras, not to solve particular data science problems as optimally as possible. Obviously, most techniques include hyper-parameters that need to be tuned for optimal performance.

# %%
# We will always initially perform all required imports
import pandas as pd 

import numpy as np

import matplotlib.pyplot as plt

from keras import Sequential
from keras.layers import Input, Dense, GaussianNoise, Dropout, BatchNormalization, Activation
from keras.utils.vis_utils import model_to_dot
from keras.models import Model
from keras.constraints import UnitNorm
from keras.regularizers import l2
from keras.callbacks import EarlyStopping
from keras.datasets import boston_housing
# Out:
# 2024-02-27 18:12:39.581587: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# We will start by loading a simple data set to work with. We will use the Boston housing price regression data that is included in Keras.datasets.

# %%
(x_train, y_train), (x_test, y_test) = boston_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 [==============================] - 0s 8us/step

# %% [markdown]
# In the next few code boxes we see a basic implementation of an MLP based approach to modeling the above dataset, of the sort that is found in many beginner tutorials. The MLP involved has two hidden layers, with four nodes in each.
#
# We set up the network by adding layers, then compile it and train it using our training data.

# %%
def define_model_1 (input_shape):
    model = Sequential()
    model.add(Dense(input_dim=input_shape,units=14,activation="relu", 
                    name = "Hidden1"))
    model.add(Dense(units=6,activation="relu",name = "Hidden2"))
    model.add(Dense(units=1,activation="linear",name="Output"))
    return model

# %% [markdown]
# Now we will define and compile the model. We'll use the adam optimizer with (binary) cross-entropy loss and track the accuracy.

# %%
model=define_model_1(x_train.shape[1])
model.compile(optimizer ='adam',
              loss='mean_squared_error')

# %% [markdown]
# We can easily get a summary of our model.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Hidden1 (Dense)             (None, 14)                196
#
#  Hidden2 (Dense)             (None, 6)                 90
#
#  Output (Dense)              (None, 1)                 7
#
# =================================================================
# Total params: 293
# Trainable params: 293
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now we fit the model to the training dataset.

# %%
history=model.fit(x_train,y_train, batch_size=64, epochs=1000)
# Out:
# Epoch 1/1000
# 7/7 [==============================] - 2s 4ms/step - loss: 717.6353
# Epoch 2/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 436.2116
# Epoch 3/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 280.8789
# Epoch 4/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 188.1922
# Epoch 5/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 133.4275
# Epoch 6/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 99.2069
# Epoch 7/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 82.1960
# Epoch 8/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 71.0539
# Epoch 9/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 66.4451
# Epoch 10/1000
# 7/7 [==============================] - 0s 12ms/step - loss: 63.6674
# Epoch 11/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 62.6046
# Epoch 12/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 61.0435
# Epoch 13/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 60.3222
# Epoch 14/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 59.6115
# Epoch 15/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 59.3652
# Epoch 16/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 58.8802
# Epoch 17/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 58.4948
# Epoch 18/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 57.8841
# Epoch 19/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 57.4601
# Epoch 20/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 57.0654
# Epoch 21/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 56.7628
# Epoch 22/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 56.4091
# Epoch 23/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 55.9714
# Epoch 24/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 55.6223
# Epoch 25/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 55.4049
# Epoch 26/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 55.0076
# Epoch 27/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 54.5810
# Epoch 28/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 54.5372
# Epoch 29/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 54.7692
# Epoch 30/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 54.8974
# Epoch 31/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 53.4853
# Epoch 32/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 53.6920
# Epoch 33/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 52.7077
# Epoch 34/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 53.2498
# Epoch 35/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 52.3223
# Epoch 36/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 52.0199
# Epoch 37/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 51.8778
# Epoch 38/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 51.5363
# Epoch 39/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 51.4590
# Epoch 40/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 51.0562
# Epoch 41/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 50.9210
# Epoch 42/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 50.6442
# Epoch 43/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 50.5103
# Epoch 44/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 50.1847
# Epoch 45/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 50.4621
# Epoch 46/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 49.6339
# Epoch 47/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 49.8794
# Epoch 48/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 49.8905
# Epoch 49/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 48.7652
# Epoch 50/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 48.6739
# Epoch 51/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 48.3507
# Epoch 52/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 48.8821
# Epoch 53/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 47.9365
# Epoch 54/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 47.9270
# Epoch 55/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 47.4956
# Epoch 56/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 47.3412
# Epoch 57/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 47.0690
# Epoch 58/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 46.9595
# Epoch 59/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 46.6606
# Epoch 60/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 46.5368
# Epoch 61/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 46.6293
# Epoch 62/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 46.1412
# Epoch 63/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 45.7365
# Epoch 64/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 45.7083
# Epoch 65/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 45.3009
# Epoch 66/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 45.1700
# Epoch 67/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 44.7200
# Epoch 68/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 44.5574
# Epoch 69/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 44.4126
# Epoch 70/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 44.3089
# Epoch 71/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 43.8050
# Epoch 72/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 43.7570
# Epoch 73/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 43.5144
# Epoch 74/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 43.4044
# Epoch 75/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 43.0368
# Epoch 76/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 43.0621
# Epoch 77/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 42.7267
# Epoch 78/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 42.7038
# Epoch 79/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 42.2137
# Epoch 80/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 42.0567
# Epoch 81/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 41.9914
# Epoch 82/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 42.9423
# Epoch 83/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 43.1892
# Epoch 84/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 42.1690
# Epoch 85/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 41.8630
# Epoch 86/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 41.0148
# Epoch 87/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 42.4248
# Epoch 88/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 40.9327
# Epoch 89/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 40.5615
# Epoch 90/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 41.6263
# Epoch 91/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 40.5008
# Epoch 92/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 39.8055
# Epoch 93/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 39.3684
# Epoch 94/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 39.5054
# Epoch 95/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 39.0678
# Epoch 96/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 38.8330
# Epoch 97/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 38.8110
# Epoch 98/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 38.3474
# Epoch 99/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 38.3339
# Epoch 100/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 37.9774
# Epoch 101/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 37.9870
# Epoch 102/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 37.7940
# Epoch 103/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 37.8254
# Epoch 104/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 37.2236
# Epoch 105/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 37.6986
# Epoch 106/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 36.9724
# Epoch 107/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 36.8665
# Epoch 108/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 36.9196
# Epoch 109/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 36.5908
# Epoch 110/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 36.3658
# Epoch 111/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 36.3928
# Epoch 112/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 36.7040
# Epoch 113/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 35.8808
# Epoch 114/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 35.4648
# Epoch 115/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 35.3913
# Epoch 116/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 35.5202
# Epoch 117/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 35.7731
# Epoch 118/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 35.7381
# Epoch 119/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 34.9797
# Epoch 120/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 34.5581
# Epoch 121/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 35.0048
# Epoch 122/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 34.4648
# Epoch 123/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 33.9943
# Epoch 124/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 34.0626
# Epoch 125/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 33.7748
# Epoch 126/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 33.3045
# Epoch 127/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 33.4046
# Epoch 128/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 33.3833
# Epoch 129/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 33.0514
# Epoch 130/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 32.8410
# Epoch 131/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 32.6469
# Epoch 132/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 32.6005
# Epoch 133/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 32.6248
# Epoch 134/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 32.6573
# Epoch 135/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 32.5433
# Epoch 136/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 32.5723
# Epoch 137/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 31.8014
# Epoch 138/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 31.6762
# Epoch 139/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 31.3616
# Epoch 140/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 31.3103
# Epoch 141/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 31.5152
# Epoch 142/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 30.9030
# Epoch 143/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 31.2281
# Epoch 144/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 30.8099
# Epoch 145/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 30.5178
# Epoch 146/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 30.6502
# Epoch 147/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 32.0630
# Epoch 148/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 30.3398
# Epoch 149/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 29.8453
# Epoch 150/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 29.5655
# Epoch 151/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 29.4099
# Epoch 152/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 29.2112
# Epoch 153/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 29.0927
# Epoch 154/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 29.5113
# Epoch 155/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 28.7850
# Epoch 156/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 28.5342
# Epoch 157/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 28.3544
# Epoch 158/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 28.6290
# Epoch 159/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 28.6179
# Epoch 160/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 29.1499
# Epoch 161/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 28.8455
# Epoch 162/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 29.0505
# Epoch 163/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 27.5998
# Epoch 164/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 27.6199
# Epoch 165/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 27.4700
# Epoch 166/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 27.2904
# Epoch 167/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 26.8480
# Epoch 168/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 27.1251
# Epoch 169/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 27.8553
# Epoch 170/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 27.3754
# Epoch 171/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 27.2039
# Epoch 172/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 26.2034
# Epoch 173/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 26.1068
# Epoch 174/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 26.2119
# Epoch 175/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 25.8462
# Epoch 176/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 25.6347
# Epoch 177/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 25.7059
# Epoch 178/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 25.3435
# Epoch 179/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 25.6164
# Epoch 180/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 25.5533
# Epoch 181/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 26.3614
# Epoch 182/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 25.8638
# Epoch 183/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 24.7759
# Epoch 184/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 25.3225
# Epoch 185/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 24.9661
# Epoch 186/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 24.6862
# Epoch 187/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 24.9444
# Epoch 188/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 24.9085
# Epoch 189/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 24.1098
# Epoch 190/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 24.1133
# Epoch 191/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 24.5146
# Epoch 192/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 24.5331
# Epoch 193/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 23.6540
# Epoch 194/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 23.6926
# Epoch 195/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 23.4403
# Epoch 196/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 23.7445
# Epoch 197/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 23.2242
# Epoch 198/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 23.1110
# Epoch 199/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 22.9723
# Epoch 200/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 23.1391
# Epoch 201/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 22.6994
# Epoch 202/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 22.7811
# Epoch 203/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 22.5620
# Epoch 204/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 22.8504
# Epoch 205/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 22.7062
# Epoch 206/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 22.4518
# Epoch 207/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 22.1503
# Epoch 208/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 22.0942
# Epoch 209/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 21.8363
# Epoch 210/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 21.9968
# Epoch 211/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 22.2283
# Epoch 212/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 21.4763
# Epoch 213/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 21.8608
# Epoch 214/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 21.7534
# Epoch 215/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 21.6416
# Epoch 216/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 21.5988
# Epoch 217/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 21.7847
# Epoch 218/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 21.1634
# Epoch 219/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 20.9419
# Epoch 220/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 21.3721
# Epoch 221/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 21.2561
# Epoch 222/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 21.2870
# Epoch 223/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 21.3861
# Epoch 224/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 21.5031
# Epoch 225/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 22.7554
# Epoch 226/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 22.3453
# Epoch 227/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 20.7722
# Epoch 228/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 20.2683
# Epoch 229/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 20.4045
# Epoch 230/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 20.5070
# Epoch 231/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 20.9070
# Epoch 232/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 20.4937
# Epoch 233/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 21.2888
# Epoch 234/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 22.1451
# Epoch 235/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 20.5763
# Epoch 236/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 19.9959
# Epoch 237/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 19.8910
# Epoch 238/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 19.6897
# Epoch 239/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 19.6709
# Epoch 240/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 20.1161
# Epoch 241/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 20.0759
# Epoch 242/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 20.6094
# Epoch 243/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 20.1150
# Epoch 244/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 19.5268
# Epoch 245/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 19.3805
# Epoch 246/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 19.4859
# Epoch 247/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 19.4926
# Epoch 248/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 19.2778
# Epoch 249/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 19.3584
# Epoch 250/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 19.0368
# Epoch 251/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 19.7451
# Epoch 252/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 19.0339
# Epoch 253/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 19.0462
# Epoch 254/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 19.1383
# Epoch 255/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 18.9795
# Epoch 256/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 19.5133
# Epoch 257/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 19.3145
# Epoch 258/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 19.1432
# Epoch 259/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 18.7069
# Epoch 260/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 18.6222
# Epoch 261/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 18.5867
# Epoch 262/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 19.0385
# Epoch 263/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 18.5026
# Epoch 264/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 18.3689
# Epoch 265/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 18.5107
# Epoch 266/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 18.2248
# Epoch 267/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 18.4967
# Epoch 268/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 18.7387
# Epoch 269/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 19.5632
# Epoch 270/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 19.6137
# Epoch 271/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 18.4336
# Epoch 272/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 18.4395
# Epoch 273/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 18.1157
# Epoch 274/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 18.2816
# Epoch 275/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 18.6007
# Epoch 276/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 18.0698
# Epoch 277/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 18.0111
# Epoch 278/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 17.8348
# Epoch 279/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 17.6142
# Epoch 280/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 17.4181
# Epoch 281/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 18.1450
# Epoch 282/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 19.1593
# Epoch 283/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 18.4098
# Epoch 284/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 17.4499
# Epoch 285/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 18.1863
# Epoch 286/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 17.4068
# Epoch 287/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 17.8139
# Epoch 288/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 17.5305
# Epoch 289/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 17.3409
# Epoch 290/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 17.2398
# Epoch 291/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 17.1735
# Epoch 292/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 17.3592
# Epoch 293/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 17.2712
# Epoch 294/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 17.2640
# Epoch 295/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 17.7106
# Epoch 296/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 17.8569
# Epoch 297/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 17.4907
# Epoch 298/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 17.1851
# Epoch 299/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 17.0927
# Epoch 300/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 17.3885
# Epoch 301/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 17.1303
# Epoch 302/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 18.1110
# Epoch 303/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 18.5550
# Epoch 304/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 17.0653
# Epoch 305/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 16.7645
# Epoch 306/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 17.4027
# Epoch 307/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 16.8605
# Epoch 308/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 16.9832
# Epoch 309/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 17.6414
# Epoch 310/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 16.9726
# Epoch 311/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 17.7037
# Epoch 312/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 17.2312
# Epoch 313/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 18.0540
# Epoch 314/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 17.0213
# Epoch 315/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 16.7600
# Epoch 316/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 17.3534
# Epoch 317/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 16.6358
# Epoch 318/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 17.0934
# Epoch 319/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 17.9941
# Epoch 320/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 17.2106
# Epoch 321/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 16.7569
# Epoch 322/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 16.5240
# Epoch 323/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 16.4817
# Epoch 324/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 16.2050
# Epoch 325/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 16.6298
# Epoch 326/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 16.1633
# Epoch 327/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 16.2449
# Epoch 328/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 16.3521
# Epoch 329/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 16.0345
# Epoch 330/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 16.9969
# Epoch 331/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 16.7325
# Epoch 332/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 16.5417
# Epoch 333/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 16.2017
# Epoch 334/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 15.9207
# Epoch 335/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 15.9518
# Epoch 336/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 15.9907
# Epoch 337/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 16.4136
# Epoch 338/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 16.3852
# Epoch 339/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 16.1179
# Epoch 340/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 15.9606
# Epoch 341/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 15.7697
# Epoch 342/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 15.8344
# Epoch 343/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 15.8328
# Epoch 344/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 15.6410
# Epoch 345/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.6397
# Epoch 346/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 15.8818
# Epoch 347/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 15.8871
# Epoch 348/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 15.7848
# Epoch 349/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 15.4626
# Epoch 350/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 15.5176
# Epoch 351/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 15.4867
# Epoch 352/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 15.4401
# Epoch 353/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 15.7455
# Epoch 354/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.3935
# Epoch 355/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.9815
# Epoch 356/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.7578
# Epoch 357/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.8136
# Epoch 358/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.8534
# Epoch 359/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.7522
# Epoch 360/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.9522
# Epoch 361/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.9317
# Epoch 362/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 15.2808
# Epoch 363/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.1254
# Epoch 364/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 15.7429
# Epoch 365/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 16.1176
# Epoch 366/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 16.4799
# Epoch 367/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 16.1470
# Epoch 368/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 15.7574
# Epoch 369/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.4659
# Epoch 370/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.5141
# Epoch 371/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.4928
# Epoch 372/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.2911
# Epoch 373/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 15.3608
# Epoch 374/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 15.2050
# Epoch 375/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.2602
# Epoch 376/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 15.0913
# Epoch 377/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.3921
# Epoch 378/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.7530
# Epoch 379/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.5926
# Epoch 380/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 15.1188
# Epoch 381/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 15.0201
# Epoch 382/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 15.0100
# Epoch 383/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 15.2962
# Epoch 384/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 15.5444
# Epoch 385/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 14.8414
# Epoch 386/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.8910
# Epoch 387/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.3292
# Epoch 388/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 14.9111
# Epoch 389/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 15.2313
# Epoch 390/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 14.6512
# Epoch 391/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.4211
# Epoch 392/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.7676
# Epoch 393/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.9032
# Epoch 394/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 14.6517
# Epoch 395/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.7819
# Epoch 396/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 16.6591
# Epoch 397/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 15.5271
# Epoch 398/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 14.8817
# Epoch 399/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 14.5833
# Epoch 400/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 14.8133
# Epoch 401/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.5319
# Epoch 402/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.5498
# Epoch 403/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.0311
# Epoch 404/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 14.6034
# Epoch 405/1000
# 7/7 [==============================] - 0s 7ms/step - loss: 14.6899
# Epoch 406/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.5126
# Epoch 407/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.5940
# Epoch 408/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.4828
# Epoch 409/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.2861
# Epoch 410/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.4007
# Epoch 411/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 14.4462
# Epoch 412/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 14.4204
# Epoch 413/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 14.3153
# Epoch 414/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 14.4625
# Epoch 415/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 14.4527
# Epoch 416/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.2171
# Epoch 417/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 14.3187
# Epoch 418/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.1734
# Epoch 419/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 14.4665
# Epoch 420/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.8821
# Epoch 421/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.6953
# Epoch 422/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.7966
# Epoch 423/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.2495
# Epoch 424/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 15.3107
# Epoch 425/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 14.9043
# Epoch 426/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.6790
# Epoch 427/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 14.1703
# Epoch 428/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.9025
# Epoch 429/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.8779
# Epoch 430/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 13.9878
# Epoch 431/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 14.0248
# Epoch 432/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.2185
# Epoch 433/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.9031
# Epoch 434/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.9788
# Epoch 435/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.8313
# Epoch 436/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.3421
# Epoch 437/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 14.5091
# Epoch 438/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 14.0660
# Epoch 439/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.8327
# Epoch 440/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.8272
# Epoch 441/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.9829
# Epoch 442/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.8287
# Epoch 443/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.6652
# Epoch 444/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.9865
# Epoch 445/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.8239
# Epoch 446/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 14.1096
# Epoch 447/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 14.3768
# Epoch 448/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.9069
# Epoch 449/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.1528
# Epoch 450/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 14.1323
# Epoch 451/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.7768
# Epoch 452/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.0471
# Epoch 453/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.9308
# Epoch 454/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 14.3047
# Epoch 455/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.4948
# Epoch 456/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.0294
# Epoch 457/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.7819
# Epoch 458/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 14.6209
# Epoch 459/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.5951
# Epoch 460/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.5590
# Epoch 461/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.6813
# Epoch 462/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.6833
# Epoch 463/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 13.9190
# Epoch 464/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 14.6590
# Epoch 465/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.4769
# Epoch 466/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.4596
# Epoch 467/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.5249
# Epoch 468/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.5211
# Epoch 469/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.3467
# Epoch 470/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.7093
# Epoch 471/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.7691
# Epoch 472/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.1282
# Epoch 473/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.8508
# Epoch 474/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.6297
# Epoch 475/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 13.6948
# Epoch 476/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.5299
# Epoch 477/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.3814
# Epoch 478/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.5588
# Epoch 479/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.6097
# Epoch 480/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.3987
# Epoch 481/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.1075
# Epoch 482/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.4679
# Epoch 483/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.1206
# Epoch 484/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.6887
# Epoch 485/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.3891
# Epoch 486/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.6079
# Epoch 487/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.6890
# Epoch 488/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.0220
# Epoch 489/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.3911
# Epoch 490/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.5403
# Epoch 491/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.4653
# Epoch 492/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.1543
# Epoch 493/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 13.3634
# Epoch 494/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.2014
# Epoch 495/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.1361
# Epoch 496/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.1175
# Epoch 497/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.0127
# Epoch 498/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.0535
# Epoch 499/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.0150
# Epoch 500/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.9085
# Epoch 501/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.0942
# Epoch 502/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 14.2267
# Epoch 503/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.1565
# Epoch 504/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.7682
# Epoch 505/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.1692
# Epoch 506/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.9263
# Epoch 507/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.7474
# Epoch 508/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.9322
# Epoch 509/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 13.5938
# Epoch 510/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 12.8519
# Epoch 511/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 12.9978
# Epoch 512/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.8238
# Epoch 513/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 13.1258
# Epoch 514/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.6057
# Epoch 515/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.2099
# Epoch 516/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.9520
# Epoch 517/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.8556
# Epoch 518/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.7647
# Epoch 519/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.0165
# Epoch 520/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.2333
# Epoch 521/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.9009
# Epoch 522/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 12.5775
# Epoch 523/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.7727
# Epoch 524/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 13.7621
# Epoch 525/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.9523
# Epoch 526/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 14.5960
# Epoch 527/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.4691
# Epoch 528/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.4711
# Epoch 529/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 12.9561
# Epoch 530/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.1521
# Epoch 531/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.4824
# Epoch 532/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.7611
# Epoch 533/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 12.5514
# Epoch 534/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.5384
# Epoch 535/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.5600
# Epoch 536/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.5291
# Epoch 537/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.6679
# Epoch 538/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.8507
# Epoch 539/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.6609
# Epoch 540/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.7020
# Epoch 541/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 12.7784
# Epoch 542/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 13.3339
# Epoch 543/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.0730
# Epoch 544/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.0160
# Epoch 545/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 13.0161
# Epoch 546/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.7235
# Epoch 547/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.6197
# Epoch 548/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.7137
# Epoch 549/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.4936
# Epoch 550/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.7538
# Epoch 551/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.5813
# Epoch 552/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.2825
# Epoch 553/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.5153
# Epoch 554/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.5014
# Epoch 555/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.7939
# Epoch 556/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.3196
# Epoch 557/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.4689
# Epoch 558/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.7013
# Epoch 559/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 12.4364
# Epoch 560/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.8923
# Epoch 561/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.9070
# Epoch 562/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.1893
# Epoch 563/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.6954
# Epoch 564/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.6806
# Epoch 565/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.5431
# Epoch 566/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.5948
# Epoch 567/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.5173
# Epoch 568/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.3282
# Epoch 569/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.3807
# Epoch 570/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.5149
# Epoch 571/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.7166
# Epoch 572/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.6371
# Epoch 573/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.4592
# Epoch 574/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.5643
# Epoch 575/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.9983
# Epoch 576/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.7063
# Epoch 577/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.8031
# Epoch 578/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.3119
# Epoch 579/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.8810
# Epoch 580/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.2370
# Epoch 581/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.0351
# Epoch 582/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.1736
# Epoch 583/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.3531
# Epoch 584/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.4516
# Epoch 585/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.5214
# Epoch 586/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.1290
# Epoch 587/1000
# ...
# Epoch 806/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 11.2871
# Epoch 807/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 12.1139
# Epoch 808/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.4136
# Epoch 809/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 11.5826
# Epoch 810/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 11.4112
# Epoch 811/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 11.5268
# Epoch 812/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 11.1928
# Epoch 813/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 11.2441
# Epoch 814/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 11.7734
# Epoch 815/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 11.6271
# Epoch 816/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 11.3343
# Epoch 817/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.7592
# Epoch 818/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.8022
# Epoch 819/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 11.1887
# Epoch 820/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 11.1194
# Epoch 821/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.9192
# Epoch 822/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.8543
# Epoch 823/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 10.7600
# Epoch 824/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.6165
# Epoch 825/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.5778
# Epoch 826/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.9160
# Epoch 827/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.8306
# Epoch 828/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 11.6955
# Epoch 829/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.9888
# Epoch 830/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 11.2218
# Epoch 831/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.9582
# Epoch 832/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.6799
# Epoch 833/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.5571
# Epoch 834/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.7219
# Epoch 835/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.8536
# Epoch 836/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.9275
# Epoch 837/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.9401
# Epoch 838/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.8517
# Epoch 839/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 10.5618
# Epoch 840/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.8861
# Epoch 841/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.9424
# Epoch 842/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.3932
# Epoch 843/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.5784
# Epoch 844/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.4462
# Epoch 845/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.5365
# Epoch 846/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.6206
# Epoch 847/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.3878
# Epoch 848/1000
# 7/7 [==============================] - 0s 15ms/step - loss: 10.4621
# Epoch 849/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.3509
# Epoch 850/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 11.0649
# Epoch 851/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 11.1905
# Epoch 852/1000
# 7/7 [==============================] - 0s 8ms/step - loss: 11.6110
# Epoch 853/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 10.9994
# Epoch 854/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 11.4300
# Epoch 855/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 11.4793
# Epoch 856/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.8628
# Epoch 857/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 10.6197
# Epoch 858/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.5412
# Epoch 859/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.4576
# Epoch 860/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.3892
# Epoch 861/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.5671
# Epoch 862/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 11.3298
# Epoch 863/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.7990
# Epoch 864/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 11.5858
# Epoch 865/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.5673
# Epoch 866/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.7008
# Epoch 867/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 11.9207
# Epoch 868/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 11.2970
# Epoch 869/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.9292
# Epoch 870/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 11.3378
# Epoch 871/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 11.1511
# Epoch 872/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.7272
# Epoch 873/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 10.9373
# Epoch 874/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.5597
# Epoch 875/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.4177
# Epoch 876/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.4978
# Epoch 877/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.4651
# Epoch 878/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 11.1004
# Epoch 879/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 10.6526
# Epoch 880/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.3629
# Epoch 881/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.4795
# Epoch 882/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.8233
# Epoch 883/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.9309
# Epoch 884/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.9897
# Epoch 885/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.0710
# Epoch 886/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 10.5167
# Epoch 887/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.4116
# Epoch 888/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.4780
# Epoch 889/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.5630
# Epoch 890/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.5288
# Epoch 891/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 10.6746
# Epoch 892/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.5927
# Epoch 893/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.4823
# Epoch 894/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.3320
# Epoch 895/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 10.3732
# Epoch 896/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.3274
# Epoch 897/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 10.3028
# Epoch 898/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.2950
# Epoch 899/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 11.0124
# Epoch 900/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 11.4326
# Epoch 901/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 12.0466
# Epoch 902/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.3735
# Epoch 903/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.6776
# Epoch 904/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 10.3448
# Epoch 905/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.4398
# Epoch 906/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.6802
# Epoch 907/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.5175
# Epoch 908/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.6584
# Epoch 909/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 13.3710
# Epoch 910/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 11.2640
# Epoch 911/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.3968
# Epoch 912/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.6627
# Epoch 913/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.5699
# Epoch 914/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.8097
# Epoch 915/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 11.0827
# Epoch 916/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.7340
# Epoch 917/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.5491
# Epoch 918/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.8872
# Epoch 919/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.8191
# Epoch 920/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.6332
# Epoch 921/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.5247
# Epoch 922/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.3873
# Epoch 923/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.3514
# Epoch 924/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.2239
# Epoch 925/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 10.4679
# Epoch 926/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.4363
# Epoch 927/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.1088
# Epoch 928/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.1891
# Epoch 929/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.3251
# Epoch 930/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.2463
# Epoch 931/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.4202
# Epoch 932/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.3999
# Epoch 933/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.5980
# Epoch 934/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 10.5968
# Epoch 935/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.3301
# Epoch 936/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.2949
# Epoch 937/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.1449
# Epoch 938/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.2950
# Epoch 939/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.5902
# Epoch 940/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.6289
# Epoch 941/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.2961
# Epoch 942/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.3112
# Epoch 943/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.6797
# Epoch 944/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.3734
# Epoch 945/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 11.0154
# Epoch 946/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.1573
# Epoch 947/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.5138
# Epoch 948/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.1573
# Epoch 949/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.3481
# Epoch 950/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 10.2101
# Epoch 951/1000
# 7/7 [==============================] - 0s 27ms/step - loss: 10.1390
# Epoch 952/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 10.2978
# Epoch 953/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 10.3629
# Epoch 954/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.2029
# Epoch 955/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 11.0188
# Epoch 956/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.9180
# Epoch 957/1000
# 7/7 [==============================] - 0s 8ms/step - loss: 10.6845
# Epoch 958/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 11.0429
# Epoch 959/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.3458
# Epoch 960/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.1471
# Epoch 961/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.3315
# Epoch 962/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.3346
# Epoch 963/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.2371
# Epoch 964/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.7243
# Epoch 965/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.8001
# Epoch 966/1000
# 7/7 [==============================] - 0s 5ms/step - loss: 10.4070
# Epoch 967/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.4518
# Epoch 968/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.1191
# Epoch 969/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.2618
# Epoch 970/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.2066
# Epoch 971/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.8425
# Epoch 972/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 9.9343
# Epoch 973/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.1392
# Epoch 974/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.0225
# Epoch 975/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 9.9864
# Epoch 976/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.5334
# Epoch 977/1000
# 7/7 [==============================] - 0s 6ms/step - loss: 10.2136
# Epoch 978/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.1134
# Epoch 979/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.1096
# Epoch 980/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.1551
# Epoch 981/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.3736
# Epoch 982/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 10.7314
# Epoch 983/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.6877
# Epoch 984/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.0277
# Epoch 985/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.1980
# Epoch 986/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.3181
# Epoch 987/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.2868
# Epoch 988/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.6935
# Epoch 989/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.7314
# Epoch 990/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 11.7443
# Epoch 991/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.3996
# Epoch 992/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.2577
# Epoch 993/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.1390
# Epoch 994/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 9.9656
# Epoch 995/1000
# 7/7 [==============================] - 0s 4ms/step - loss: 10.1674
# Epoch 996/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.8422
# Epoch 997/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 10.4675
# Epoch 998/1000
# 7/7 [==============================] - 0s 2ms/step - loss: 10.1108
# Epoch 999/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.0266
# Epoch 1000/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 10.0298

# %% [markdown]
# Let's make a function to graph the mean squared error loss during training from the history object returned by model.fit, and then call this function.

# %%
def plot_training_history_1(history):
    plt.plot(history.history['loss'])
    plt.title('Model loss')
    plt.xlabel('Epoch')
    plt.gca().set_ylim(0,150)
    plt.gca().set_xlim(0,len(history.history['loss']))
    plt.show()

# %%
plot_training_history_1(history)

# %% [markdown]
# We'll also create a function that examines how well a model does on known data by means of a confusion matrix, and call it with our basic model and test data.

# %%
def test_model(model,x,y):
    y_pred = model.predict(x)
    mse=np.mean((y - y_pred)**2)
    print ("Mean Squared Error: {}".format(mse))

# %%
test_model(model,x_test,y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step
# Mean Squared Error: 150.0085856692484

# %% [markdown]
# ## Improving our simple implementation: Step 1
#
# The above code is both basic and **bad**. We will go through looking at how we can change things to both make it reasonable - by using validation data, regularization, batch normalization and early stopping) - as well as introducing more advanced Keras functionality. There are four changes we will make.
#
# Later in this course we are going to end up looking at models that include multiple input and output layers and/or shared layers. To work with these we will want to use keras' functional API and the keras.Model function rather than keras.Sequential.
#
# **So our first change will be to alter our define_model function to use the functional API instead of a Sequential model.**

# %%
def define_model_2 (input_shape):
    # We start by defining the input layer using Input. 
    # This returns a tensor
    inputs = Input(shape=(input_shape,),name="Input")
    
    # Now we create the remaining layers. A layer instance is 
    # a function that is callable on a tensor, and returns a tensor.
    hidden1 = Dense(14, activation='relu',name="Hidden1")(inputs)
    hidden2 = Dense(6, activation='relu',name="Hidden2")(hidden1)
    outputs = Dense(1, activation='linear',name="Output")(hidden2)
    
    # Now we use the model function to creates a model that includes 
    # the input layer through to the output layer. Note that each 
    # layer knows its predecessor/input layer, so the model graph 
    # can be traced back from outputs until it reaches inputs.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# ## Improving our simple implementation: Step 2
#
# We typically need to regularize our neural networks. Regularization provides a means of controlling the complexity of a model without changing its structure (i.e. its basic parametric equation). Common forms of regularization include:
#     - L1/L2 regularization, which restricts the ability of model parameters to freely take on large values by means of penalizing large L1 or L2 norms of the weight vector. L2 regularization is also known as weight decay. You can read more about L1 and L2 regularization in Keras [here](https://machinelearningmastery.com/how-to-reduce-generalization-error-in-deep-neural-networks-with-activity-regularization-in-keras/).
#     - Weight constraints, which constrains the weights to have a particular norm. You can read more about weight constraints [here](https://machinelearningmastery.com/how-to-reduce-overfitting-in-deep-neural-networks-with-weight-constraints-in-keras/).
#     - Dropout, which (under one interpretation) restricts the ability of model parameters to jointly tune. You can read more
# about dropout [here](https://machinelearningmastery.com/dropout-regularization-deep-learning-models-keras/).
#     - Noise injection, which restricts the ability of the model parameters to fit themselves to exact values found in the training data. Read more about using noise injection with keras.Sequential models and a case study [here](https://machinelearningmastery.com/how-to-improve-deep-learning-model-robustness-by-adding-noise/).
#
# **For our second improvement, let's change the above code to include L2 regularization.**
#
# Note that you will see dropout, weight constraints and noise injection regularization methods in later modules.

# %%
# In this version, when we create the hidden layers, we add l2 
# regularization (also known as weight decay). 
# 
# We have to provide a hyper-parameter to specify the degree of 
# regularization to be imposed. We could have different degrees 
# of regularization for each layer, but we will not. Instead we 
# will allow the user to specify the degree of regularization to
# be used in both layers, and give a default value of .1.
#
# Note that L1 regularization is applied in an analgous way, only 
# using regularizers.l1 instead of regularizers.l2.
def define_model_3 (input_shape,l2_param=.1):
    inputs = Input(shape=(input_shape,),name="Input")
    
    # Now we add regularization to the hidden layers
    hidden1 = Dense(14, activation='relu',name="Hidden1",
                   kernel_regularizer=l2(l2_param))(inputs)
    hidden2 = Dense(6, activation='relu',name="Hidden2",
                   kernel_regularizer=l2(l2_param))(hidden1)

    outputs = Dense(1, activation='linear',name="Output")(hidden2)
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# ## Improving our simple implementation: Step 3
#
# We normally want to speed up the training process as much as possible. Batch normalization is a technique that helps do this by seeking to minimize the changes to distributions that latter layers have to learn during the fitting process. Read more about batch normalization [here](https://towardsdatascience.com/batch-normalization-in-neural-networks-1ac91516821c).
#
# **For our third improvement, let's change the above code to include batch normalization.**

# %%
def define_model_4 (input_shape,l2_param=.1):
    inputs = Input(shape=(input_shape,),name="Input")

    # We do not want any activation function defined inside
    # the layer. To do this we just need to not specify any 
    # (by default the activation of a Dense layer is None). 
    # We also do not want a bias node/weight, since the batch 
    # normalization has a parameter that takes care of that.
    # So we set use_bias to False.
    hidden1 = Dense(14,name="Hidden1",use_bias=False, 
                    kernel_regularizer=l2(l2_param))(inputs)
    # By adding the Batch Normalization layer here, we apply a 
    # transformation that maintains the mean close to 0 and the 
    # activation standard deviation close to 1. This is done *prior*
    # to the application of the activation function.
    batch1 = BatchNormalization(name="BatchNorm1")(hidden1)
    # Now we apply the activation function.
    act1 = Activation("relu",name="Activation1")(batch1)

    # We do the same thing with the second hidden layer
    hidden2 = Dense(6,name="Hidden2",use_bias=False, 
                    kernel_regularizer=l2(l2_param))(act1)
    batch2 = BatchNormalization(name="BatchNorm2")(hidden2)
    act2 = Activation("relu",name="Activation2")(batch2)

    # Now we do the output layer and the model
    outputs = Dense(1, activation='linear',name="Output")(act2)
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# ## Improving our simple implementation: Step 4
#
# We want to find the parameter (weight) values that minimize the expected error on new data, not the error on training data. So we should be using validation data to evaluate the performance of the model after each epoch, and choose the final weights that correspond to optimal performance on this validation data.
#
# **For our final improvement, when training we will evaluate the performance of our model after each epoch using validation data, and combine this with an early stopping callback that will both stop training once performance on the validation data deteriorates and load the weights associated with best performance on the validation data into our final model.**

# %%
# Let's define our model using our improved code.
model=define_model_4(x_train.shape[1])

# And we will compile it.
model.compile(optimizer ='adam',
              loss='mse')

# Before calling fit, we create the Early Stopping callback. 
# We set it up to stop if improvement in the validation loss 
# does not occur over 15 epochs. When stopping occurs, the 
# weights associated with the best validation loss are restored.
earlyStopping = EarlyStopping(monitor="val_loss", 
                              patience=15,
                              verbose=1,
                              restore_best_weights=True)

# Using validation_split in the model.fit function can be dangerous as 
# it takes last rows prior to shuffling. If data order is not random, this
# can lead to introduction of bias into the data. It is OK here since 
# the data was shuffled during the train/test split above.    
history=model.fit(x_train, 
                  y_train, 
                  epochs=1000, 
                  batch_size=10, 
                  shuffle=True, 
                  validation_split=.2, 
                  callbacks=[earlyStopping])
# Out:
# Epoch 1/1000
# 33/33 [==============================] - 4s 16ms/step - loss: 565.9381 - val_loss: 691.2740
# Epoch 2/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 551.7268 - val_loss: 646.7401
# Epoch 3/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 541.0848 - val_loss: 610.5620
# Epoch 4/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 528.2728 - val_loss: 591.2318
# Epoch 5/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 518.6146 - val_loss: 580.9542
# Epoch 6/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 507.5398 - val_loss: 573.8635
# Epoch 7/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 497.4104 - val_loss: 556.9656
# Epoch 8/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 485.2624 - val_loss: 555.2699
# Epoch 9/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 473.0565 - val_loss: 553.8550
# Epoch 10/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 459.5648 - val_loss: 546.3984
# Epoch 11/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 449.0059 - val_loss: 539.5729
# Epoch 12/1000
# 33/33 [==============================] - 0s 7ms/step - loss: 435.9497 - val_loss: 533.1547
# Epoch 13/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 420.6100 - val_loss: 510.2663
# Epoch 14/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 411.6676 - val_loss: 494.7756
# Epoch 15/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 397.4347 - val_loss: 475.2725
# Epoch 16/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 382.2735 - val_loss: 453.5430
# Epoch 17/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 371.7813 - val_loss: 426.9946
# Epoch 18/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 361.1101 - val_loss: 410.8565
# Epoch 19/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 349.3735 - val_loss: 404.9950
# Epoch 20/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 333.3320 - val_loss: 377.6250
# Epoch 21/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 320.5566 - val_loss: 365.9945
# Epoch 22/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 310.1106 - val_loss: 365.1575
# Epoch 23/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 295.6232 - val_loss: 372.1929
# Epoch 24/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 281.8223 - val_loss: 355.7594
# Epoch 25/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 268.7780 - val_loss: 359.5725
# Epoch 26/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 254.6849 - val_loss: 346.7516
# Epoch 27/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 245.4498 - val_loss: 272.2136
# Epoch 28/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 230.6878 - val_loss: 272.8568
# Epoch 29/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 222.7910 - val_loss: 175.5109
# Epoch 30/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 209.6426 - val_loss: 114.6356
# Epoch 31/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 197.1458 - val_loss: 78.9264
# Epoch 32/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 189.4107 - val_loss: 92.8616
# Epoch 33/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 173.2624 - val_loss: 111.7167
# Epoch 34/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 165.7921 - val_loss: 105.5804
# Epoch 35/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 155.1700 - val_loss: 109.4151
# Epoch 36/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 149.6563 - val_loss: 112.0196
# Epoch 37/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 136.3741 - val_loss: 132.9414
# Epoch 38/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 124.9357 - val_loss: 135.7455
# Epoch 39/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 122.8464 - val_loss: 143.5768
# Epoch 40/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 115.7972 - val_loss: 112.2179
# Epoch 41/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 106.0823 - val_loss: 76.5137
# Epoch 42/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 106.5440 - val_loss: 122.0190
# Epoch 43/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 93.7646 - val_loss: 87.9346
# Epoch 44/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 93.2425 - val_loss: 108.7221
# Epoch 45/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 86.6170 - val_loss: 66.8574
# Epoch 46/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 81.0154 - val_loss: 95.0247
# Epoch 47/1000
# 33/33 [==============================] - 0s 7ms/step - loss: 76.0603 - val_loss: 85.9016
# Epoch 48/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 72.6341 - val_loss: 103.8827
# Epoch 49/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 75.1934 - val_loss: 49.6000
# Epoch 50/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 62.8177 - val_loss: 35.0861
# Epoch 51/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 61.2636 - val_loss: 55.3968
# Epoch 52/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 60.9830 - val_loss: 32.6763
# Epoch 53/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 54.2572 - val_loss: 32.3340
# Epoch 54/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 50.4669 - val_loss: 33.7665
# Epoch 55/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 48.1208 - val_loss: 37.1892
# Epoch 56/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 48.7326 - val_loss: 34.5089
# Epoch 57/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 44.1101 - val_loss: 28.0215
# Epoch 58/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 48.2098 - val_loss: 27.3712
# Epoch 59/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 49.9199 - val_loss: 27.5000
# Epoch 60/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 38.0049 - val_loss: 28.9205
# Epoch 61/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 40.3560 - val_loss: 34.8742
# Epoch 62/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 47.0788 - val_loss: 22.9513
# Epoch 63/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 37.9609 - val_loss: 25.7471
# Epoch 64/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 38.5014 - val_loss: 30.8043
# Epoch 65/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 40.3442 - val_loss: 27.9415
# Epoch 66/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 36.8127 - val_loss: 25.3000
# Epoch 67/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 39.1063 - val_loss: 35.8250
# Epoch 68/1000
# 33/33 [==============================] - 0s 7ms/step - loss: 37.9785 - val_loss: 32.4363
# Epoch 69/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 38.8538 - val_loss: 22.4168
# Epoch 70/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 32.6774 - val_loss: 26.0828
# Epoch 71/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 40.2910 - val_loss: 23.8832
# Epoch 72/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 35.8688 - val_loss: 27.7222
# Epoch 73/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 36.3270 - val_loss: 20.4252
# Epoch 74/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 32.6494 - val_loss: 20.0806
# Epoch 75/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 33.0062 - val_loss: 21.0801
# Epoch 76/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 34.8362 - val_loss: 25.6084
# Epoch 77/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 33.2421 - val_loss: 32.3727
# Epoch 78/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 34.9919 - val_loss: 30.0107
# Epoch 79/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 30.2495 - val_loss: 28.4732
# Epoch 80/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 30.0810 - val_loss: 25.1748
# Epoch 81/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 28.1063 - val_loss: 22.2522
# Epoch 82/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 32.4260 - val_loss: 21.5611
# Epoch 83/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 31.6529 - val_loss: 18.8238
# Epoch 84/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 31.0895 - val_loss: 19.5522
# Epoch 85/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 32.8460 - val_loss: 21.2080
# Epoch 86/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 33.9289 - val_loss: 22.1719
# Epoch 87/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 31.3629 - val_loss: 17.6355
# Epoch 88/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 34.8422 - val_loss: 21.6151
# Epoch 89/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 31.9500 - val_loss: 21.3655
# Epoch 90/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 33.4691 - val_loss: 21.7175
# Epoch 91/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 32.4042 - val_loss: 19.9490
# Epoch 92/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 38.6165 - val_loss: 20.1045
# Epoch 93/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 29.3216 - val_loss: 19.0353
# Epoch 94/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 32.6724 - val_loss: 19.8170
# Epoch 95/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 31.4589 - val_loss: 24.6822
# Epoch 96/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 34.2691 - val_loss: 21.3754
# Epoch 97/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 33.8475 - val_loss: 19.4516
# Epoch 98/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 32.0823 - val_loss: 18.3607
# Epoch 99/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 28.2006 - val_loss: 20.9694
# Epoch 100/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 33.8617 - val_loss: 32.9806
# Epoch 101/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 35.2739 - val_loss: 19.4868
# Epoch 102/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 29.1381 - val_loss: 17.5701
# Epoch 103/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 35.6272 - val_loss: 16.7380
# Epoch 104/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 29.1600 - val_loss: 17.3285
# Epoch 105/1000
# 33/33 [==============================] - 0s 7ms/step - loss: 32.1181 - val_loss: 18.8735
# Epoch 106/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 30.1188 - val_loss: 18.4790
# Epoch 107/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 31.8322 - val_loss: 21.7374
# Epoch 108/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 32.9251 - val_loss: 17.6766
# Epoch 109/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 28.4988 - val_loss: 20.8131
# Epoch 110/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 30.8631 - val_loss: 20.3468
# Epoch 111/1000
# 33/33 [==============================] - 0s 8ms/step - loss: 31.2797 - val_loss: 17.3184
# Epoch 112/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 32.4890 - val_loss: 18.5493
# Epoch 113/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 30.6476 - val_loss: 19.8010
# Epoch 114/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 28.9289 - val_loss: 19.7006
# Epoch 115/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 31.3038 - val_loss: 18.2820
# Epoch 116/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 31.0647 - val_loss: 17.6037
# Epoch 117/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 32.0670 - val_loss: 17.0799
# Epoch 118/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 29.6681 - val_loss: 16.6497
# Epoch 119/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 29.4839 - val_loss: 17.4678
# Epoch 120/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 32.8286 - val_loss: 18.6182
# Epoch 121/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 32.0567 - val_loss: 16.4283
# Epoch 122/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 28.9944 - val_loss: 17.3764
# Epoch 123/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 33.1322 - val_loss: 17.2377
# Epoch 124/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 26.6412 - val_loss: 19.7160
# Epoch 125/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 30.7233 - val_loss: 17.5966
# Epoch 126/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 26.8810 - val_loss: 16.9623
# Epoch 127/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 29.7207 - val_loss: 27.6144
# Epoch 128/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 25.5599 - val_loss: 22.3280
# Epoch 129/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 29.6900 - val_loss: 17.1948
# Epoch 130/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 26.4867 - val_loss: 17.4611
# Epoch 131/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 32.9696 - val_loss: 19.2537
# Epoch 132/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 27.8992 - val_loss: 16.0704
# Epoch 133/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 27.5451 - val_loss: 18.9746
# Epoch 134/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 29.2914 - val_loss: 17.7024
# Epoch 135/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 31.5990 - val_loss: 19.3026
# Epoch 136/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 29.1917 - val_loss: 19.4456
# Epoch 137/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 26.5027 - val_loss: 17.4382
# Epoch 138/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 33.4299 - val_loss: 21.4140
# Epoch 139/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 30.5682 - val_loss: 18.0896
# Epoch 140/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 30.5078 - val_loss: 17.6447
# Epoch 141/1000
# 33/33 [==============================] - 0s 4ms/step - loss: 36.7327 - val_loss: 37.0499
# Epoch 142/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 27.4440 - val_loss: 27.9269
# Epoch 143/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 26.9259 - val_loss: 18.7537
# Epoch 144/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 28.6959 - val_loss: 19.8855
# Epoch 145/1000
# 33/33 [==============================] - 0s 6ms/step - loss: 33.3958 - val_loss: 16.9024
# Epoch 146/1000
# 33/33 [==============================] - 0s 5ms/step - loss: 32.9698 - val_loss: 18.1938
# Epoch 147/1000
# 32/33 [============================>.] - ETA: 0s - loss: 30.5994Restoring model weights from the end of the best epoch: 132.
# 33/33 [==============================] - 0s 6ms/step - loss: 30.8125 - val_loss: 20.1558
# Epoch 147: early stopping

# %% [markdown]
# If you want to, run the code below to see the model summary.

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 13)]              0
#
#  Hidden1 (Dense)             (None, 14)                182
#
#  BatchNorm1 (BatchNormalizat  (None, 14)               56
#  ion)
#
#  Activation1 (Activation)    (None, 14)                0
#
#  Hidden2 (Dense)             (None, 6)                 84
#
#  BatchNorm2 (BatchNormalizat  (None, 6)                24
#  ion)
#
#  Activation2 (Activation)    (None, 6)                 0
#
#  Output (Dense)              (None, 1)                 7
#
# =================================================================
# Total params: 353
# Trainable params: 313
# Non-trainable params: 40
# _________________________________________________________________

# %% [markdown]
# Let's improve our plot_training_history function so that it also displays both training and validation mean squared error. Then we will call this improved version.

# %%
def plot_training_history_2(history):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Training and Validation Mean Squared Error')
    plt.xlabel('Epoch')    
    plt.gca().set_ylim(0,150)
    plt.gca().set_xlim(0,len(history.history['loss']))
    plt.show()

# %%
plot_training_history_2(history)

# %% [markdown]
# Finally, for fun lets see how our improved model performs on our test data. But remember that we have not spent any time or effort optimizing this model - for a real problem we would determine good values for the l2 regularization, as well as tune the architecture and optimizer.

# %%
test_model(model,x_test,y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step
# Mean Squared Error: 138.66924364030467
